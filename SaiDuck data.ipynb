# %%
import pandas as pd

# %%
dataset = pd.read_csv(r"C:\Users\sadha\OneDrive\Desktop\supply_chain.csv", encoding="ISO-8859-1")

# %%
pd.set_option('display.max_columns', 33)
# dataset[dataset['PO Sent to Vendor Date'] == 'Date Not Captured']
dataset[dataset['Dosage'].notnull()]

# dataset
# Out:
#           ID Project Code            PQ # PO / SO # ASN/DN #        Country  \
# 1          3   108-VN-T01  Pre-PQ Process   SCMS-13   ASN-85        Vietnam
# 3         15   108-VN-T01  Pre-PQ Process   SCMS-78   ASN-50        Vietnam
# 4         16   108-VN-T01  Pre-PQ Process   SCMS-81   ASN-55        Vietnam
# 5         23   112-NG-T01  Pre-PQ Process   SCMS-87   ASN-57        Nigeria
# 6         44   110-ZM-T01  Pre-PQ Process  SCMS-139  ASN-130         Zambia
# ...      ...          ...             ...       ...      ...            ...
# 10319  86818   103-ZW-T30       FPQ-15197  SO-50020  DN-4307       Zimbabwe
# 10320  86819   104-CI-T30       FPQ-15259  SO-50102  DN-4313  Côte d'Ivoire
# 10321  86821   110-ZM-T30       FPQ-14784  SO-49600  DN-4316         Zambia
# 10322  86822   200-ZW-T30       FPQ-16523  SO-51680  DN-4334       Zimbabwe
# 10323  86823   103-ZW-T30       FPQ-15197  SO-50022  DN-4336       Zimbabwe
#
# ...

# %%
dataset.dropna(how = 'any').shape
# Out:
# (8158, 33)

# %%
dataset2 = dataset.dropna(how = 'any')

# %%
dataset2.to_csv(r"C:\Users\sadha\OneDrive\Desktop\supply_chain2.csv")

# %%
dataset2
# Out:
#           ID Project Code            PQ #   PO / SO #  ASN/DN #  \
# 21       108   104-CI-T01  Pre-PQ Process    SCMS-698   ASN-727
# 22       115   108-VN-T01  Pre-PQ Process    SCMS-753   ASN-781
# 23       116   108-VN-T01  Pre-PQ Process    SCMS-759   ASN-632
# 29       161   117-ET-T01  Pre-PQ Process  SCMS-11070   ASN-916
# 32       269   108-VN-T01  Pre-PQ Process  SCMS-14190  ASN-1192
# ...      ...          ...             ...         ...       ...
# 10319  86818   103-ZW-T30       FPQ-15197    SO-50020   DN-4307
# 10320  86819   104-CI-T30       FPQ-15259    SO-50102   DN-4313
# 10321  86821   110-ZM-T30       FPQ-14784    SO-49600   DN-4316
# 10322  86822   200-ZW-T30       FPQ-16523    SO-51680   DN-4334
# 10323  86823   103-ZW-T30       FPQ-15197    SO-50022   DN-4336
#
#              Country Managed By  Fulfill Via Vendor INCO Term Shipment Mode  \
# 21     Côte d'Ivoire   PMO - US  Direct Drop              CIP           Air
# ...

# %%
Pediatricdataset = dataset[dataset['Sub Classification'] == 'Pediatric']

# %%
Pediatricdataset
# Out:
#           ID Project Code            PQ # PO / SO # ASN/DN #   Country  \
# 1          3   108-VN-T01  Pre-PQ Process   SCMS-13   ASN-85   Vietnam
# 5         23   112-NG-T01  Pre-PQ Process   SCMS-87   ASN-57   Nigeria
# 6         44   110-ZM-T01  Pre-PQ Process  SCMS-139  ASN-130    Zambia
# 15        68   113-ZW-T01  Pre-PQ Process  SCMS-308  ASN-285  Zimbabwe
# 18        87   109-TZ-T01  Pre-PQ Process  SCMS-555  ASN-409  Tanzania
# ...      ...          ...             ...       ...      ...       ...
# 10312  86810   114-UG-T30       FPQ-15294  SO-50054  DN-4265    Uganda
# 10314  86813   151-NG-T30       FPQ-14989  SO-51422  DN-4274   Nigeria
# 10318  86817   103-ZW-T30       FPQ-15197  SO-50020  DN-4307  Zimbabwe
# 10319  86818   103-ZW-T30       FPQ-15197  SO-50020  DN-4307  Zimbabwe
# 10323  86823   103-ZW-T30       FPQ-15197  SO-50022  DN-4336  Zimbabwe
#
#       Managed By  Fulfill Via Vendor INCO Term Shipment Mode  \
# ...

# %%
dataset3 = dataset2[dataset2['PO Sent to Vendor Date'] != 'Date Not Captured']

# %%
dataset3 = dataset2[dataset2['PO Sent to Vendor Date'] != 'N/A - From RDC']

# %%
dataset3 = dataset2[dataset2['Vendor INCO Term'] != 'N/A - From RDC']

# %%
dataset3.to_csv(r"C:\Users\sadha\OneDrive\Desktop\supply_chain3.csv")

# %%
dataset3
# Out:
#          ID Project Code            PQ #    PO / SO #   ASN/DN #  \
# 21      108   104-CI-T01  Pre-PQ Process     SCMS-698    ASN-727
# 22      115   108-VN-T01  Pre-PQ Process     SCMS-753    ASN-781
# 23      116   108-VN-T01  Pre-PQ Process     SCMS-759    ASN-632
# 29      161   117-ET-T01  Pre-PQ Process   SCMS-11070    ASN-916
# 32      269   108-VN-T01  Pre-PQ Process   SCMS-14190   ASN-1192
# ...     ...          ...             ...          ...        ...
# 6575  82159   151-NG-T30       FPQ-16553  SCMS-296460  ASN-33764
# 6576  82172   108-VN-T30        FPQ-6384   SCMS-87780   ASN-9408
# 6577  82177   108-VN-T30       FPQ-14516  SCMS-249050  ASN-29372
# 6578  82203   106-HT-T30       FPQ-11285  SCMS-176250  ASN-18844
# 6579  82256   116-ZA-T30        FPQ-3596   SCMS-50370   ASN-5458
#
#             Country Managed By  Fulfill Via Vendor INCO Term Shipment Mode  \
# 21    Côte d'Ivoire   PMO - US  Direct Drop              CIP           Air
# ...

# %%
dataset4 = dataset3[dataset3['Weight (Kilograms)'] != 'Weight Captured Separately']

# %%
dataset4
# Out:
#          ID Project Code            PQ #    PO / SO #   ASN/DN #  \
# 21      108   104-CI-T01  Pre-PQ Process     SCMS-698    ASN-727
# 22      115   108-VN-T01  Pre-PQ Process     SCMS-753    ASN-781
# 23      116   108-VN-T01  Pre-PQ Process     SCMS-759    ASN-632
# 29      161   117-ET-T01  Pre-PQ Process   SCMS-11070    ASN-916
# 32      269   108-VN-T01  Pre-PQ Process   SCMS-14190   ASN-1192
# ...     ...          ...             ...          ...        ...
# 6571  82125   113-ZW-T30       FPQ-13939  SCMS-240570  ASN-27582
# 6573  82137   161-ZA-T30        FPQ-5303   SCMS-68940   ASN-8246
# 6576  82172   108-VN-T30        FPQ-6384   SCMS-87780   ASN-9408
# 6577  82177   108-VN-T30       FPQ-14516  SCMS-249050  ASN-29372
# 6578  82203   106-HT-T30       FPQ-11285  SCMS-176250  ASN-18844
#
#             Country Managed By  Fulfill Via Vendor INCO Term Shipment Mode  \
# 21    Côte d'Ivoire   PMO - US  Direct Drop              CIP           Air
# ...

# %%
dataset5 = dataset4[dataset4['Freight Cost (USD)'] != 'Freight Included in Commodity Cost']

# %%
dataset5
# Out:
#          ID Project Code            PQ #    PO / SO #   ASN/DN #  \
# 22      115   108-VN-T01  Pre-PQ Process     SCMS-753    ASN-781
# 23      116   108-VN-T01  Pre-PQ Process     SCMS-759    ASN-632
# 29      161   117-ET-T01  Pre-PQ Process   SCMS-11070    ASN-916
# 32      269   108-VN-T01  Pre-PQ Process   SCMS-14190   ASN-1192
# 33      270   108-VN-T01  Pre-PQ Process   SCMS-14200   ASN-1171
# ...     ...          ...             ...          ...        ...
# 6571  82125   113-ZW-T30       FPQ-13939  SCMS-240570  ASN-27582
# 6573  82137   161-ZA-T30        FPQ-5303   SCMS-68940   ASN-8246
# 6576  82172   108-VN-T30        FPQ-6384   SCMS-87780   ASN-9408
# 6577  82177   108-VN-T30       FPQ-14516  SCMS-249050  ASN-29372
# 6578  82203   106-HT-T30       FPQ-11285  SCMS-176250  ASN-18844
#
#            Country Managed By  Fulfill Via Vendor INCO Term Shipment Mode  \
# 22         Vietnam   PMO - US  Direct Drop              EXW           Air
# ...

# %%
hivtestdataset = dataset[dataset['Sub Classification'] == 'HIV test']

# %%
hivtestdataset2 = hivtestdataset[hivtestdataset['PO Sent to Vendor Date'] != 'Date Not Captured']

# %%
hivtestdataset3 = hivtestdataset2[hivtestdataset2['PO Sent to Vendor Date'] != 'N/A - From RDC']

# %%
hivtestdataset3.to_csv(r"C:\Users\sadha\OneDrive\Desktop\supply_chainHIV.csv")

# %%
Pediatricdataset = dataset5[dataset5['Sub Classification'] == 'Pediatric']

# %%
Pediatricdataset.to_csv(r"C:\Users\sadha\OneDrive\Desktop\supply_chainPediatric.csv")

# %%
Adultdataset = dataset5[dataset5['Sub Classification'] == 'Adult']

# %%
Adultdataset.to_csv(r"C:\Users\sadha\OneDrive\Desktop\supply_chainAdult.csv")

# %%
malariadataset = dataset5[dataset5['Sub Classification'] == 'Malaria']

# %%
malariadataset.to_csv(r"C:\Users\sadha\OneDrive\Desktop\supply_chainmalaria.csv")

# %%
actdataset = dataset5[dataset5['Sub Classification'] == 'ACT']

# %%
actdataset.to_csv(r"C:\Users\sadha\OneDrive\Desktop\supply_chainact.csv")

# %%
hivtestancillarydataset = dataset[dataset['Sub Classification'] == 'HIV test - Ancillary']

# %%
hivtestancillarydataset.to_csv(r"C:\Users\sadha\OneDrive\Desktop\supply_chainAncillary.csv")
